# %% [markdown]
# # Chapter 4
#
# Types of corruption
# -  Multipath
# -  Changing gain
# -  Other signals
# -  Broadband Noise (aka thermal noise, white noise)
# -  Narrowband Noise
#
# Fading is another type of corruption (probably fits under the Changing Gain bullet). This is a changing of the frequency response of the channel over time.
#
# ## Impulse Response
#
# The impulse (or delta) function $\delta(t)$

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#listing 4.1 specdelta.m
# modified for exercise 4.5
time = 2
Ts = 1.0/100
t = np.linspace(0, time, int(time/Ts) + 1)
x = np.zeros(len(t))
spacing = 20
for i in range(len(t)):
    if i % spacing == 1:
        x[i] = 1

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, x)

fourier = np.fft.fft(x)
n = len(x)
freq = np.fft.fftfreq(n, d=Ts)
axs[1].plot(freq, abs(fourier))
## answer to part c
print((1/Ts)/spacing)
# Out:
# <img src="data:image/png;base64,..." width="826">
# 5.0
